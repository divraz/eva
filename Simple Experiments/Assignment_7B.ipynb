# %% [markdown]
# <a href="https://colab.research.google.com/github/divyanshuraj6815/eva/blob/master/Project%201/Assignment_7B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout, Conv2D, Input, DepthwiseConv2D, Concatenate
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras import layers, models

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)
cardinality = 32

# %%
#call heavenly Gods
from keras import layers

#define global parameters
img_width = 32
img_height = 32
img_channels = 3

def assignment_7B (x):
  
  def add_common_layers (y):
    y = layers.BatchNormalization ()(y)
    y = layers.Activation ('relu')(y)
    y = layers.Dropout (0.1)(y)
    return y
  
  def concat (y):
    y = layers.concatenate (y)
    y = add_common_layers (y)
    return y
  
  def space_to_depth (y, input_shape, output_shape):
    no_of_groups = int (input_shape / output_shape)
    counter = int (input_shape / no_of_groups)
    
    n = list ()
    groups = []
    for i in range (0, input_shape + 1, counter):
      if i == 0:
        n.append (i)
      elif i == input_shape:
        n.append (i - 1)
      else:
        n.append (i - 1)
        n.append (i)
   
    z = []
    for i, x in enumerate (n):
      if i % 2 == 0:
        z.append ([n[i], n[i + 1]])
    #print (z) 
    groups = []
    for i in z:
      for j in z:
        group = layers.Lambda (lambda x: x[:, i[0]:i[1]+1, j[0]:j[1]+1, :])(y)
        #print (group.shape)
        groups.append (group)
    
    y = layers.concatenate (groups)
    return y

  def sep (y, channel_size, kernel_size, history, count):
    y = layers.SeparableConv2D(channel_size, (kernel_size, kernel_size), padding='same', use_bias=False, depthwise_initializer='glorot_uniform', pointwise_initializer='glorot_uniform')(y)
    y = add_common_layers (y)
    #index = 0
    history.append (y)
    count += 1
    return (y, history, count)
  
  def conv (y, channel_size, kernel_size, history, count):
    y = layers.Conv2D (channel_size, (kernel_size, kernel_size), strides = (1, 1), padding = 'same')(y)
    y = add_common_layers (y)
    #index = 0
    history.append (y)
    count += 1
    return (y, history, count)
    
  def block_1 (y, history, count):
    #index = 0
    (y, history, count) = sep (y, 48, 5, history, count)
    #index = 1
    (y, history, count) = conv (y, 48, 5, history, count)
    #index = 2
    (y, history, count) = conv (y, 48, 5, history, count)
    #index = 3
    (y, history, count) = sep (concat ([y, history[0]]), 48, 5, history, count)
    
    return (concat ([y, history[0]]), history, count)

  def block_2 (y, history, count):
    #index = 5
    (y, history, count) = sep (y, 96, 3, history, count)
    #index = 6
    (y, history, count) = conv (concat ([y, 
                                         space_to_depth (history[0], 32, 16), 
                                         space_to_depth (history[3], 32, 16)]),
                                96, 
                                5, 
                                history, count)
    #index = 7
    (y, history, count) = sep (concat ([y, 
                                        space_to_depth (history[0], 32, 16), 
                                        space_to_depth (history[3], 32, 16), 
                                        history[5]]), 
                               96, 
                               3, 
                               history, count)
    #index = 8
    (y, history, count) = sep (concat ([y, 
                                        space_to_depth (history[0], 32, 16), 
                                        space_to_depth (history[2], 32, 16), 
                                        space_to_depth (history[3], 32, 16),
                                        history[5]]), 
                               96, 
                               5, 
                               history, count)
    
    return (concat ([y, 
                     space_to_depth (history[0], 32, 16), 
                     space_to_depth (history[3], 32, 16), 
                     history[5], 
                     history[7]]), 
            history, 
            count)

  def block_3 (y, history, count):
    #index = 10
    (y, history, count) = conv (concat ([y, 
                                         space_to_depth (history[6], 16, 8)]),
                                192, 
                                5, 
                                history, count)
    #index = 11
    (y, history, count) = sep (concat ([y, 
                                        space_to_depth (history[0], 32, 8), 
                                        space_to_depth (history[1], 32, 8), 
                                        space_to_depth (history[7], 16, 8)]), 
                               192, 
                               5, 
                               history, count)
    #index = 12
    (y, history, count) = conv (concat ([y, 
                                        space_to_depth (history[1], 32, 8), 
                                        space_to_depth (history[2], 32, 8),
                                        space_to_depth (history[5], 16, 8), 
                                        history[10]]), 
                               192, 
                               3, 
                               history, count)
    #index = 13
    (y, history, count) = sep (concat ([y, 
                                        space_to_depth (history[0], 32, 8), 
                                        space_to_depth (history[2], 32, 8),
                                        space_to_depth (history[3], 32, 8),
                                        space_to_depth (history[5], 16, 8),
                                        space_to_depth (history[7], 16, 8),
                                        history[11]]), 
                               192, 
                               5, 
                               history, count)
    
    return (concat ([y, 
                     space_to_depth (history[3], 32, 8), 
                     space_to_depth (history[7], 16, 8), 
                     history[11]]), 
            history, 
            count)
  
  history = []
  count = -1
  
  #part 1
  (x, history, count) = block_1 (x, history, count)
  print (count)
  #index = 4
  x = layers.MaxPooling2D((2, 2))(x)
  x = add_common_layers (x)
  history.append (x)
  count += 1
  
  #part 2
  (x, history, count) = block_2 (x, history, count)
  print (count)
  #index = 9
  x = layers.MaxPooling2D((2, 2))(x)
  x = add_common_layers (x)
  history.append (x)
  count += 1
  
  #part 3
  (x, history, count) = block_3 (x, history, count)
  print (count)
  #index = 14
  x = add_common_layers (x)
  x = layers.Conv2D(10, (8, 8), use_bias=False)(x)
  history.append (x)
  count += 1

  x = layers.Flatten()(x)
  x = layers.Activation ('softmax')(x)
  history.append (x)
  count += 1
  
  for i, element in enumerate (history):
    print (i, element.shape)
  return x

image_tensor = layers.Input(shape=(img_height, img_width, img_channels))
network_output = assignment_7B (image_tensor)
  
model = models.Model(inputs=[image_tensor], outputs=[network_output])
print(model.summary())
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# 3
# 8
# 13
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_29 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_89 (SeparableC (None, 32, 32, 48)   219         input_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 32, 32, 48)   192         separable_conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 32, 32, 48)   0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# dropout_256 (Dropout)           (None, 32, 32, 48)   0           activation_270[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 32, 32, 48)   57648       dropout_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 32, 32, 48)   192         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 32, 32, 48)   0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# dropout_257 (Dropout)           (None, 32, 32, 48)   0           activation_271[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 32, 32, 48)   57648       dropout_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 32, 32, 48)   192         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 32, 32, 48)   0           batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# dropout_258 (Dropout)           (None, 32, 32, 48)   0           activation_272[0][0]
# __________________________________________________________________________________________________
# concatenate_180 (Concatenate)   (None, 32, 32, 96)   0           dropout_258[0][0]
#                                                                  dropout_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 32, 32, 96)   384         concatenate_180[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 32, 32, 96)   0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# dropout_259 (Dropout)           (None, 32, 32, 96)   0           activation_273[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_90 (SeparableC (None, 32, 32, 48)   7008        dropout_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 32, 32, 48)   192         separable_conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 32, 32, 48)   0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# dropout_260 (Dropout)           (None, 32, 32, 48)   0           activation_274[0][0]
# __________________________________________________________________________________________________
# concatenate_181 (Concatenate)   (None, 32, 32, 96)   0           dropout_260[0][0]
#                                                                  dropout_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 32, 32, 96)   384         concatenate_181[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 32, 32, 96)   0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# dropout_261 (Dropout)           (None, 32, 32, 96)   0           activation_275[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 16, 16, 96)   0           dropout_261[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 16, 16, 96)   384         max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 16, 16, 96)   0           batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# dropout_262 (Dropout)           (None, 16, 16, 96)   0           activation_276[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_91 (SeparableC (None, 16, 16, 96)   10080       dropout_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 16, 16, 96)   384         separable_conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 16, 16, 96)   0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# lambda_573 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_574 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_575 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_576 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_577 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_578 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_579 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_580 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# dropout_263 (Dropout)           (None, 16, 16, 96)   0           activation_277[0][0]
# __________________________________________________________________________________________________
# concatenate_182 (Concatenate)   (None, 16, 16, 192)  0           lambda_573[0][0]
#                                                                  lambda_574[0][0]
#                                                                  lambda_575[0][0]
#                                                                  lambda_576[0][0]
# __________________________________________________________________________________________________
# concatenate_183 (Concatenate)   (None, 16, 16, 192)  0           lambda_577[0][0]
#                                                                  lambda_578[0][0]
#                                                                  lambda_579[0][0]
#                                                                  lambda_580[0][0]
# __________________________________________________________________________________________________
# concatenate_184 (Concatenate)   (None, 16, 16, 480)  0           dropout_263[0][0]
#                                                                  concatenate_182[0][0]
#                                                                  concatenate_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 16, 16, 480)  1920        concatenate_184[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 16, 16, 480)  0           batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# dropout_264 (Dropout)           (None, 16, 16, 480)  0           activation_278[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 96)   1152096     dropout_264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 16, 16, 96)   384         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 16, 16, 96)   0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# lambda_581 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_582 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_583 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_584 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_585 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_586 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_587 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_588 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# dropout_265 (Dropout)           (None, 16, 16, 96)   0           activation_279[0][0]
# __________________________________________________________________________________________________
# concatenate_185 (Concatenate)   (None, 16, 16, 192)  0           lambda_581[0][0]
#                                                                  lambda_582[0][0]
#                                                                  lambda_583[0][0]
#                                                                  lambda_584[0][0]
# __________________________________________________________________________________________________
# concatenate_186 (Concatenate)   (None, 16, 16, 192)  0           lambda_585[0][0]
#                                                                  lambda_586[0][0]
#                                                                  lambda_587[0][0]
#                                                                  lambda_588[0][0]
# __________________________________________________________________________________________________
# concatenate_187 (Concatenate)   (None, 16, 16, 576)  0           dropout_265[0][0]
#                                                                  concatenate_185[0][0]
#                                                                  concatenate_186[0][0]
#                                                                  dropout_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 16, 16, 576)  2304        concatenate_187[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 16, 16, 576)  0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# dropout_266 (Dropout)           (None, 16, 16, 576)  0           activation_280[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_92 (SeparableC (None, 16, 16, 96)   60480       dropout_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 16, 16, 96)   384         separable_conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 16, 16, 96)   0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# lambda_589 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_590 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_591 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_592 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_593 (Lambda)             (None, 16, 16, 48)   0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_594 (Lambda)             (None, 16, 16, 48)   0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_595 (Lambda)             (None, 16, 16, 48)   0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_596 (Lambda)             (None, 16, 16, 48)   0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_597 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_598 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_599 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_600 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# dropout_267 (Dropout)           (None, 16, 16, 96)   0           activation_281[0][0]
# __________________________________________________________________________________________________
# concatenate_188 (Concatenate)   (None, 16, 16, 192)  0           lambda_589[0][0]
#                                                                  lambda_590[0][0]
#                                                                  lambda_591[0][0]
#                                                                  lambda_592[0][0]
# __________________________________________________________________________________________________
# concatenate_189 (Concatenate)   (None, 16, 16, 192)  0           lambda_593[0][0]
#                                                                  lambda_594[0][0]
#                                                                  lambda_595[0][0]
#                                                                  lambda_596[0][0]
# __________________________________________________________________________________________________
# concatenate_190 (Concatenate)   (None, 16, 16, 192)  0           lambda_597[0][0]
#                                                                  lambda_598[0][0]
#                                                                  lambda_599[0][0]
#                                                                  lambda_600[0][0]
# __________________________________________________________________________________________________
# concatenate_191 (Concatenate)   (None, 16, 16, 768)  0           dropout_267[0][0]
#                                                                  concatenate_188[0][0]
#                                                                  concatenate_189[0][0]
#                                                                  concatenate_190[0][0]
#                                                                  dropout_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 16, 16, 768)  3072        concatenate_191[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 16, 16, 768)  0           batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# dropout_268 (Dropout)           (None, 16, 16, 768)  0           activation_282[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_93 (SeparableC (None, 16, 16, 96)   92928       dropout_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 16, 16, 96)   384         separable_conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 16, 16, 96)   0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# lambda_601 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_602 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_603 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_604 (Lambda)             (None, 16, 16, 48)   0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_605 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_606 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_607 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_608 (Lambda)             (None, 16, 16, 48)   0           dropout_260[0][0]
# __________________________________________________________________________________________________
# dropout_269 (Dropout)           (None, 16, 16, 96)   0           activation_283[0][0]
# __________________________________________________________________________________________________
# concatenate_192 (Concatenate)   (None, 16, 16, 192)  0           lambda_601[0][0]
#                                                                  lambda_602[0][0]
#                                                                  lambda_603[0][0]
#                                                                  lambda_604[0][0]
# __________________________________________________________________________________________________
# concatenate_193 (Concatenate)   (None, 16, 16, 192)  0           lambda_605[0][0]
#                                                                  lambda_606[0][0]
#                                                                  lambda_607[0][0]
#                                                                  lambda_608[0][0]
# __________________________________________________________________________________________________
# concatenate_194 (Concatenate)   (None, 16, 16, 672)  0           dropout_269[0][0]
#                                                                  concatenate_192[0][0]
#                                                                  concatenate_193[0][0]
#                                                                  dropout_263[0][0]
#                                                                  dropout_267[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 16, 16, 672)  2688        concatenate_194[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 16, 16, 672)  0           batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# dropout_270 (Dropout)           (None, 16, 16, 672)  0           activation_284[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 8, 8, 672)    0           dropout_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 8, 8, 672)    2688        max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 8, 8, 672)    0           batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# lambda_609 (Lambda)             (None, 8, 8, 96)     0           dropout_265[0][0]
# __________________________________________________________________________________________________
# lambda_610 (Lambda)             (None, 8, 8, 96)     0           dropout_265[0][0]
# __________________________________________________________________________________________________
# lambda_611 (Lambda)             (None, 8, 8, 96)     0           dropout_265[0][0]
# __________________________________________________________________________________________________
# lambda_612 (Lambda)             (None, 8, 8, 96)     0           dropout_265[0][0]
# __________________________________________________________________________________________________
# dropout_271 (Dropout)           (None, 8, 8, 672)    0           activation_285[0][0]
# __________________________________________________________________________________________________
# concatenate_195 (Concatenate)   (None, 8, 8, 384)    0           lambda_609[0][0]
#                                                                  lambda_610[0][0]
#                                                                  lambda_611[0][0]
#                                                                  lambda_612[0][0]
# __________________________________________________________________________________________________
# concatenate_196 (Concatenate)   (None, 8, 8, 1056)   0           dropout_271[0][0]
#                                                                  concatenate_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 8, 8, 1056)   4224        concatenate_196[0][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 8, 8, 1056)   0           batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# dropout_272 (Dropout)           (None, 8, 8, 1056)   0           activation_286[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 192)    5068992     dropout_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 8, 8, 192)    768         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 8, 8, 192)    0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# lambda_613 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_614 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_615 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_616 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_617 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_618 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_619 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_620 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_621 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_622 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_623 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_624 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_625 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_626 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_627 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_628 (Lambda)             (None, 8, 8, 48)     0           dropout_256[0][0]
# __________________________________________________________________________________________________
# lambda_629 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_630 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_631 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_632 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_633 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_634 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_635 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_636 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_637 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_638 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_639 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_640 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_641 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_642 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_643 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_644 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_645 (Lambda)             (None, 8, 8, 96)     0           dropout_267[0][0]
# __________________________________________________________________________________________________
# lambda_646 (Lambda)             (None, 8, 8, 96)     0           dropout_267[0][0]
# __________________________________________________________________________________________________
# lambda_647 (Lambda)             (None, 8, 8, 96)     0           dropout_267[0][0]
# __________________________________________________________________________________________________
# lambda_648 (Lambda)             (None, 8, 8, 96)     0           dropout_267[0][0]
# __________________________________________________________________________________________________
# dropout_273 (Dropout)           (None, 8, 8, 192)    0           activation_287[0][0]
# __________________________________________________________________________________________________
# concatenate_197 (Concatenate)   (None, 8, 8, 768)    0           lambda_613[0][0]
#                                                                  lambda_614[0][0]
#                                                                  lambda_615[0][0]
#                                                                  lambda_616[0][0]
#                                                                  lambda_617[0][0]
#                                                                  lambda_618[0][0]
#                                                                  lambda_619[0][0]
#                                                                  lambda_620[0][0]
#                                                                  lambda_621[0][0]
#                                                                  lambda_622[0][0]
#                                                                  lambda_623[0][0]
#                                                                  lambda_624[0][0]
#                                                                  lambda_625[0][0]
#                                                                  lambda_626[0][0]
#                                                                  lambda_627[0][0]
#                                                                  lambda_628[0][0]
# __________________________________________________________________________________________________
# concatenate_198 (Concatenate)   (None, 8, 8, 768)    0           lambda_629[0][0]
#                                                                  lambda_630[0][0]
#                                                                  lambda_631[0][0]
#                                                                  lambda_632[0][0]
#                                                                  lambda_633[0][0]
#                                                                  lambda_634[0][0]
#                                                                  lambda_635[0][0]
#                                                                  lambda_636[0][0]
#                                                                  lambda_637[0][0]
#                                                                  lambda_638[0][0]
#                                                                  lambda_639[0][0]
#                                                                  lambda_640[0][0]
#                                                                  lambda_641[0][0]
#                                                                  lambda_642[0][0]
#                                                                  lambda_643[0][0]
#                                                                  lambda_644[0][0]
# __________________________________________________________________________________________________
# concatenate_199 (Concatenate)   (None, 8, 8, 384)    0           lambda_645[0][0]
#                                                                  lambda_646[0][0]
#                                                                  lambda_647[0][0]
#                                                                  lambda_648[0][0]
# __________________________________________________________________________________________________
# concatenate_200 (Concatenate)   (None, 8, 8, 2112)   0           dropout_273[0][0]
#                                                                  concatenate_197[0][0]
#                                                                  concatenate_198[0][0]
#                                                                  concatenate_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 8, 8, 2112)   8448        concatenate_200[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 8, 8, 2112)   0           batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# dropout_274 (Dropout)           (None, 8, 8, 2112)   0           activation_288[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_94 (SeparableC (None, 8, 8, 192)    458304      dropout_274[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 8, 8, 192)    768         separable_conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 8, 8, 192)    0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# lambda_649 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_650 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_651 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_652 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_653 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_654 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_655 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_656 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_657 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_658 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_659 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_660 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_661 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_662 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_663 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_664 (Lambda)             (None, 8, 8, 48)     0           dropout_257[0][0]
# __________________________________________________________________________________________________
# lambda_665 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_666 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_667 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_668 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_669 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_670 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_671 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_672 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_673 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_674 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_675 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_676 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_677 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_678 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# __________________________________________________________________________________________________
# lambda_679 (Lambda)             (None, 8, 8, 48)     0           dropout_258[0][0]
# ...
#                                                                  lambda_694[0][0]
#                                                                  lambda_695[0][0]
#                                                                  lambda_696[0][0]
#                                                                  lambda_697[0][0]
#                                                                  lambda_698[0][0]
#                                                                  lambda_699[0][0]
#                                                                  lambda_700[0][0]
# __________________________________________________________________________________________________
# concatenate_206 (Concatenate)   (None, 8, 8, 768)    0           lambda_701[0][0]
#                                                                  lambda_702[0][0]
#                                                                  lambda_703[0][0]
#                                                                  lambda_704[0][0]
#                                                                  lambda_705[0][0]
#                                                                  lambda_706[0][0]
#                                                                  lambda_707[0][0]
#                                                                  lambda_708[0][0]
#                                                                  lambda_709[0][0]
#                                                                  lambda_710[0][0]
#                                                                  lambda_711[0][0]
#                                                                  lambda_712[0][0]
#                                                                  lambda_713[0][0]
#                                                                  lambda_714[0][0]
#                                                                  lambda_715[0][0]
#                                                                  lambda_716[0][0]
# __________________________________________________________________________________________________
# concatenate_207 (Concatenate)   (None, 8, 8, 768)    0           lambda_717[0][0]
#                                                                  lambda_718[0][0]
#                                                                  lambda_719[0][0]
#                                                                  lambda_720[0][0]
#                                                                  lambda_721[0][0]
#                                                                  lambda_722[0][0]
#                                                                  lambda_723[0][0]
#                                                                  lambda_724[0][0]
#                                                                  lambda_725[0][0]
#                                                                  lambda_726[0][0]
#                                                                  lambda_727[0][0]
#                                                                  lambda_728[0][0]
#                                                                  lambda_729[0][0]
#                                                                  lambda_730[0][0]
#                                                                  lambda_731[0][0]
#                                                                  lambda_732[0][0]
# __________________________________________________________________________________________________
# concatenate_208 (Concatenate)   (None, 8, 8, 384)    0           lambda_733[0][0]
#                                                                  lambda_734[0][0]
#                                                                  lambda_735[0][0]
#                                                                  lambda_736[0][0]
# __________________________________________________________________________________________________
# concatenate_209 (Concatenate)   (None, 8, 8, 384)    0           lambda_737[0][0]
#                                                                  lambda_738[0][0]
#                                                                  lambda_739[0][0]
#                                                                  lambda_740[0][0]
# __________________________________________________________________________________________________
# concatenate_210 (Concatenate)   (None, 8, 8, 3456)   0           dropout_277[0][0]
#                                                                  concatenate_205[0][0]
#                                                                  concatenate_206[0][0]
#                                                                  concatenate_207[0][0]
#                                                                  concatenate_208[0][0]
#                                                                  concatenate_209[0][0]
#                                                                  dropout_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 8, 8, 3456)   13824       concatenate_210[0][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 8, 8, 3456)   0           batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# dropout_278 (Dropout)           (None, 8, 8, 3456)   0           activation_292[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_95 (SeparableC (None, 8, 8, 192)    749952      dropout_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 8, 8, 192)    768         separable_conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 8, 8, 192)    0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# lambda_741 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_742 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_743 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_744 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_745 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_746 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_747 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_748 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_749 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_750 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_751 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_752 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_753 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_754 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_755 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_756 (Lambda)             (None, 8, 8, 48)     0           dropout_260[0][0]
# __________________________________________________________________________________________________
# lambda_757 (Lambda)             (None, 8, 8, 96)     0           dropout_267[0][0]
# __________________________________________________________________________________________________
# lambda_758 (Lambda)             (None, 8, 8, 96)     0           dropout_267[0][0]
# __________________________________________________________________________________________________
# lambda_759 (Lambda)             (None, 8, 8, 96)     0           dropout_267[0][0]
# __________________________________________________________________________________________________
# lambda_760 (Lambda)             (None, 8, 8, 96)     0           dropout_267[0][0]
# __________________________________________________________________________________________________
# dropout_279 (Dropout)           (None, 8, 8, 192)    0           activation_293[0][0]
# __________________________________________________________________________________________________
# concatenate_211 (Concatenate)   (None, 8, 8, 768)    0           lambda_741[0][0]
#                                                                  lambda_742[0][0]
#                                                                  lambda_743[0][0]
#                                                                  lambda_744[0][0]
#                                                                  lambda_745[0][0]
#                                                                  lambda_746[0][0]
#                                                                  lambda_747[0][0]
#                                                                  lambda_748[0][0]
#                                                                  lambda_749[0][0]
#                                                                  lambda_750[0][0]
#                                                                  lambda_751[0][0]
#                                                                  lambda_752[0][0]
#                                                                  lambda_753[0][0]
#                                                                  lambda_754[0][0]
#                                                                  lambda_755[0][0]
#                                                                  lambda_756[0][0]
# __________________________________________________________________________________________________
# concatenate_212 (Concatenate)   (None, 8, 8, 384)    0           lambda_757[0][0]
#                                                                  lambda_758[0][0]
#                                                                  lambda_759[0][0]
#                                                                  lambda_760[0][0]
# __________________________________________________________________________________________________
# concatenate_213 (Concatenate)   (None, 8, 8, 1536)   0           dropout_279[0][0]
#                                                                  concatenate_211[0][0]
#                                                                  concatenate_212[0][0]
#                                                                  dropout_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 8, 8, 1536)   6144        concatenate_213[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 8, 8, 1536)   0           batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# dropout_280 (Dropout)           (None, 8, 8, 1536)   0           activation_294[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 8, 8, 1536)   6144        dropout_280[0][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 8, 8, 1536)   0           batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# dropout_281 (Dropout)           (None, 8, 8, 1536)   0           activation_295[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 1, 1, 10)     983040      dropout_281[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 10)           0           conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 10)           0           flatten_15[0][0]
# ==================================================================================================
# Total params: 12,747,099
# Trainable params: 12,713,499
# Non-trainable params: 33,600
# __________________________________________________________________________________________________
# None

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accurac